# %%
import pandas as pd

# %%
store=pd.read_csv("C:\\Users\\hemanth\\Downloads\\JigSaw\\Day 12\\PythonForModellers-master\\
PythonForModellers-master\\Data\\store.csv",encoding="latin1")

# %%
# filters
# orders/sort
# Add new col
# group by 
# strings
# date

# %%
store.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2013-152156   11/9/2013  11/12/2013    Second Class    CG-12520
# 1       2  CA-2013-152156   11/9/2013  11/12/2013    Second Class    CG-12520
# 2       3  CA-2013-138688   6/13/2013   6/17/2013    Second Class    DV-13045
# 3       4  US-2012-108966  10/11/2012  10/18/2012  Standard Class    SO-20335
# 4       5  US-2012-108966  10/11/2012  10/18/2012  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City    ...     \
# 0      Claire Gute   Consumer  United States        Henderson    ...
# 1      Claire Gute   Consumer  United States        Henderson    ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles    ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale    ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale    ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
store['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
# to get the subset of the segment == cosumer

sub1=store[store['Segment']=='Consumer']

# %%
# to get the rows and cols in the dataframe
sub1.shape
# Out:
# (5191, 21)

# %%
sub2=store[(store['Segment']=='Consumer') | (store['Segment']=='Corporate')]

# %%
sub3=store[(store['Segment']=='Consumer') | (store['Segment']=='Corporate')]['Country']
type(sub3)
# Out:
# pandas.core.series.Series

# %%
# using the query function in pandas
store.query("Segment=='Consumer' or Segment=='Corporate'")

# %%
# sorting the data frame 
store.sort_values(by="Profit",ascending=False)

# %%
# sorting using multiple cols
store.sort_values(by=["Sales","Profit"],ascending=[True,False])
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 4101    4102  US-2014-102288   6/20/2014   6/24/2014  Standard Class
# 9292    9293  CA-2014-124114    3/3/2014    3/3/2014        Same Day
# 8658    8659  CA-2013-168361   6/22/2013   6/26/2013  Standard Class
# 4711    4712  CA-2011-112403   3/31/2011   3/31/2011        Same Day
# 2106    2107  US-2011-152723   9/26/2011   9/26/2011        Same Day
# 7548    7549  CA-2011-103492  10/10/2011  10/15/2011  Standard Class
# 8033    8034  CA-2012-119690   6/25/2012   6/28/2012     First Class
# 2761    2762  CA-2014-126536  10/13/2014  10/15/2014     First Class
# 8024    8025  CA-2011-129189   7/21/2011   7/25/2011  Standard Class
# 976      977  US-2014-100209   7/10/2014   7/16/2014  Standard Class
# 4933    4934  CA-2012-106978   9/28/2012   10/4/2012  Standard Class
# 1332    1333  CA-2011-122567   2/17/2011   2/22/2011  Standard Class
# 987      988  CA-2012-146829   3/10/2012   3/10/2012        Same Day
# ...
