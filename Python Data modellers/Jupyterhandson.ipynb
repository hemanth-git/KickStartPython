# %%
import pandas as pd
path_to_file="C:\\Users\\hemanth\\Downloads\\JigSaw\\Day 12\\PythonForModellers-master\\PythonForModellers-master\\Data\\dm.csv"
data=pd.read_csv(path_to_file)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
print(data)
# Out:
#         Age  Gender OwnHome  Married Location  Salary  Children History  \
# 0       Old  Female     Own   Single      Far   47500         0    High
# 1    Middle    Male    Rent   Single    Close   63600         0    High
# 2     Young  Female    Rent   Single    Close   13500         0     Low
# 3    Middle    Male     Own  Married    Close   85600         1    High
# 4    Middle  Female     Own   Single    Close   68400         0    High
# 5     Young    Male     Own  Married    Close   30400         0     Low
# 6    Middle  Female    Rent   Single    Close   48100         0  Medium
# 7    Middle    Male     Own   Single    Close   68400         0    High
# 8    Middle  Female     Own  Married    Close   51900         3     Low
# 9       Old    Male     Own  Married      Far   80700         0     NaN
# 10    Young    Male    Rent  Married    Close   43700         1     NaN
# 11   Middle    Male     Own  Married      Far  111800         3    High
# ...

# %%
data.head()
# Out:
#       Age  Gender OwnHome  Married Location  Salary  Children History  \
# 0     Old  Female     Own   Single      Far   47500         0    High
# 1  Middle    Male    Rent   Single    Close   63600         0    High
# 2   Young  Female    Rent   Single    Close   13500         0     Low
# 3  Middle    Male     Own  Married    Close   85600         1    High
# 4  Middle  Female     Own   Single    Close   68400         0    High
#
#    Catalogs  AmountSpent  Cust_Id
# 0         6          755      247
# 1         6         1318      127
# 2        18          296      479
# 3        18         2436      475
# 4        12         1304      151

# %%
data['Age']
# Out:
# 0         Old
# 1      Middle
# 2       Young
# 3      Middle
# 4      Middle
# 5       Young
# 6      Middle
# 7      Middle
# 8      Middle
# 9         Old
# 10      Young
# 11     Middle
# 12     Middle
# 13     Middle
# 14        Old
# 15     Middle
# 16        Old
# 17     Middle
# 18     Middle
# 19        Old
# 20      Young
# 21      Young
# 22        Old
# 23      Young
# 24      Young
# 25     Middle
# 26     Middle
# 27     Middle
# 28     Middle
# 29      Young
#         ...
# 970     Young
# 971       Old
# 972    Middle
# 973    Middle
# 974     Young
# 975    Middle
# 976    Middle
# 977    Middle
# 978    Middle
# 979    Middle
# 980       Old
# 981    Middle
# 982    Middle
# 983     Young
# 984       Old
# 985    Middle
# 986       Old
# 987       Old
# 988    Middle
# 989    Middle
# 990    Middle
# 991       Old
# 992    Middle
# 993    Middle
# 994     Young
# 995     Young
# 996    Middle
# 997       Old
# 998    Middle
# 999     Young
# ...

# %%
data[['Age','Gender']]
# Out:
#         Age  Gender
# 0       Old  Female
# 1    Middle    Male
# 2     Young  Female
# 3    Middle    Male
# 4    Middle  Female
# 5     Young    Male
# 6    Middle  Female
# 7    Middle    Male
# 8    Middle  Female
# 9       Old    Male
# 10    Young    Male
# 11   Middle    Male
# 12   Middle  Female
# 13   Middle    Male
# 14      Old  Female
# 15   Middle  Female
# 16      Old  Female
# 17   Middle    Male
# 18   Middle    Male
# 19      Old  Female
# 20    Young  Female
# 21    Young    Male
# 22      Old  Female
# 23    Young    Male
# 24    Young  Female
# 25   Middle  Female
# 26   Middle    Male
# 27   Middle  Female
# 28   Middle  Female
# 29    Young    Male
# ..      ...     ...
# 970   Young  Female
# 971     Old  Female
# 972  Middle    Male
# 973  Middle  Female
# 974   Young    Male
# 975  Middle    Male
# 976  Middle    Male
# 977  Middle  Female
# 978  Middle    Male
# 979  Middle  Female
# 980     Old  Female
# 981  Middle  Female
# 982  Middle  Female
# ...

# %%
# .iloc[] is the row indexer
data[['Age','Gender']].iloc[[0,1]]
# Out:
#       Age  Gender
# 0     Old  Female
# 1  Middle    Male

# %%
# series is vector in python
type(data['Age'])
# Out:
# pandas.core.series.Series

# %%
data['Salary'].astype('float')
# Out:
# 0       47500.0
# 1       63600.0
# 2       13500.0
# 3       85600.0
# 4       68400.0
# 5       30400.0
# 6       48100.0
# 7       68400.0
# 8       51900.0
# 9       80700.0
# 10      43700.0
# 11     111800.0
# 12      44100.0
# 13     111400.0
# 14     110000.0
# 15      83100.0
# 16      82800.0
# 17      90100.0
# 18      38600.0
# 19      14000.0
# 20      14300.0
# 21      49800.0
# 22      60200.0
# 23      43500.0
# 24      41700.0
# 25      92300.0
# 26      62800.0
# 27      72900.0
# 28      66900.0
# 29      21700.0
#          ...
# 970     25300.0
# 971     43600.0
# 972     83600.0
# 973     56200.0
# 974     45500.0
# 975     99300.0
# 976    108000.0
# 977     84900.0
# 978     93000.0
# 979     82000.0
# 980     33000.0
# 981     36900.0
# 982     33200.0
# 983     49300.0
# 984     66200.0
# 985     96800.0
# 986     63200.0
# 987    112900.0
# 988     32100.0
# 989    102700.0
# 990    123800.0
# 991     11700.0
# 992    101700.0
# 993     99200.0
# ...

# %%
#summary in R
data.describe()
# Out:
#               Salary    Children     Catalogs  AmountSpent      Cust_Id
# count    1000.000000  1000.00000  1000.000000  1000.000000  1000.000000
# mean    56103.900000     0.93400    14.682000  1216.770000   643.930000
# std     30616.314826     1.05107     6.622895   961.068613   369.047166
# min     10100.000000     0.00000     6.000000    38.000000    12.000000
# 25%     29975.000000     0.00000     6.000000   488.250000   316.750000
# 50%     53700.000000     1.00000    12.000000   962.000000   636.000000
# 75%     77025.000000     2.00000    18.000000  1688.500000   955.500000
# max    168800.000000     3.00000    24.000000  6217.000000  1297.000000

# %%
# str() for structure in R
data.dtypes
# Out:
# Age            object
# Gender         object
# OwnHome        object
# Married        object
# Location       object
# Salary          int64
# Children        int64
# History        object
# Catalogs        int64
# AmountSpent     int64
# Cust_Id         int64
# dtype: object

# %%
# rename a column names returns the data frame
data.rename(columns={'Location':'Loc'})
# Out:
#         Age  Gender OwnHome  Married    Loc  Salary  Children History  \
# 0       Old  Female     Own   Single    Far   47500         0    High
# 1    Middle    Male    Rent   Single  Close   63600         0    High
# 2     Young  Female    Rent   Single  Close   13500         0     Low
# 3    Middle    Male     Own  Married  Close   85600         1    High
# 4    Middle  Female     Own   Single  Close   68400         0    High
# 5     Young    Male     Own  Married  Close   30400         0     Low
# 6    Middle  Female    Rent   Single  Close   48100         0  Medium
# 7    Middle    Male     Own   Single  Close   68400         0    High
# 8    Middle  Female     Own  Married  Close   51900         3     Low
# 9       Old    Male     Own  Married    Far   80700         0     NaN
# 10    Young    Male    Rent  Married  Close   43700         1     NaN
# 11   Middle    Male     Own  Married    Far  111800         3    High
# ...

# %%
# Out:
#       Age  Gender OwnHome  Married Location  Salary  Children History  \
# 0     Old  Female     Own   Single      Far   47500         0    High
# 1  Middle    Male    Rent   Single    Close   63600         0    High
# 2   Young  Female    Rent   Single    Close   13500         0     Low
# 3  Middle    Male     Own  Married    Close   85600         1    High
# 4  Middle  Female     Own   Single    Close   68400         0    High
#
#    Catalogs  AmountSpent  Cust_Id
# 0         6          755      247
# 1         6         1318      127
# 2        18          296      479
# 3        18         2436      475
# 4        12         1304      151
