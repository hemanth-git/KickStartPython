# %%
# reading the data of decathlon.txt file
import os
import pandas as pd

# %%
con=open("C:\\Users\\hemanth\\Downloads\\JigSaw\\Day 12\\PythonForModellers-master\\PythonForModellers-master\\Data\\decatthlon.txt","r")

# %%
data=con.read()
# Out:
# 'Whitefield, Bengaluru-560048,ITPB Main Road,Mahadevpura\nDecathlon Anubhava,Bellary Road, Bengaluru - 562157,Survey No-78/10, A2 Chikajala Village, Bellary Road\nSarjapur,Bengaluru - 560035,Survey 96/1, Sarjapur Road\nOld Madras Road,K R Puram, Bengaluru - 560049,Survey No. 39/3, Bandapura Village, Bidahalli Hobli\nMysore Road, Bengaluru - 560074,2.5 Km after Nice Road Junction,Next to KAVCON Factory, Bengaluru - 560074, Karnataka.\nBannerghatta, Bengaluru - 560076,Raj Alkaa Park, Joseph garden,Kalena Agrahara village, Bannerghatta road, Begur hobli, Bengaluru - 560076, Karnataka.\nHosur Road, Bengaluru - 560099,#242, Bommasandra Industrial Area,Next to D Mart and Indian Oil Petrol Pump Hosur Road, Bengaluru - 560099, Karnataka.\nNext to Applewoods Township, Near Shantipura crossroads, Sardar Patel Ring Road , Ahmedabad - 380058, Gujarat.\nGT Bypass road Next Khanna Paper Mill , Amritsar - 143001, Punjab.\nProzone Mall,Ground Floor,P-80,MIDC,Chikalthana, Aurangabad - 431001, Maharas
# ...

# %%
listdata=data.split("\n")

# %%
demodf=pd.DataFrame()

# %%
for li in listdata:
    templi=li.split(",")
    demodf.append(templi)

# %%
# Reading the mmwoes.csv file to a data frame
import pandas as pd
datamm=pd.read_csv("C:\\Users\\hemanth\\Downloads\\JigSaw\\Day 12\\PythonForModellers-master\\
PythonForModellers-master\\Data\\MMwoes.csv",skiprows=1)

# %%
datamm.head()
# Out:
#       id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  54734      80364      25000        25000         19419.94   36 months
# 1  55742     114426       7000         7000          6549.40   36 months
# 2  57245     138150       1200         1200          1200.00   36 months
# 3  57416     139635      10800        10800         10637.65   36 months
# 4  58524     149512       7200         7200          1800.00   36 months
#
#       apr int_rate  installment grade         ...         total_pymnt_inv  \
# 0  13.62%   11.89%       829.10     B         ...                23345.15
# 1  11.40%   10.71%       228.22     B         ...                 7758.80
# 2  16.22%   13.11%        40.50     C         ...                 1457.31
# 3  16.17%   13.57%       366.86     C         ...                13009.30
# 4  22.81%   19.05%       264.11     D         ...                  526.16
#
#   total_rec_prncp total_rec_int total_rec_late_fee  last_pymnt_d  \
# ...

# %%
datamm.dtypes
# Out:
# id                                  int64
# member_id                           int64
# loan_amnt                           int64
# funded_amnt                         int64
# funded_amnt_inv                   float64
# term                               object
# apr                                object
# int_rate                           object
# installment                       float64
# grade                              object
# sub_grade                          object
# emp_name                           object
# emp_length                         object
# home_ownership                     object
# annual_inc                          int64
# is_inc_v                             bool
# accept_d                           object
# exp_d                              object
# list_d                             object
# issue_d                            object
# loan_status                        object
# pymnt_plan                         object
# ...

# %%
datamm.columns
datamm.rename(columns={"int_rate":"interest_rate"})
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0     54734      80364      25000        25000     19419.940000   36 months
# 1     55742     114426       7000         7000      6549.400000   36 months
# 2     57245     138150       1200         1200      1200.000000   36 months
# 3     57416     139635      10800        10800     10637.650000   36 months
# 4     58524     149512       7200         7200      1800.000000   36 months
# 5     58915     153417       7500         5025      4912.740000   36 months
# 6     59006     154254       3000         3000      3000.000000   36 months
# 7     61390     182594       4000         4000      3900.000000   36 months
# 8     61419     182917       5600         5600      5525.000000   36 months
# 9     62102     191024       3200         3200      3200.000000   36 months
# 10    65426     232106       4000         4000      4000.000000   36 months
# ...

# %%
# dataframe pd.DataFrame({'colname':list})
